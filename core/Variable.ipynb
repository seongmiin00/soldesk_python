# %%
print('2024 & K-Digital')
print("2024 & K-Digital")
# print('"2024 & K-Digital"')
# Out:
# 2024 & K-Digital

# %%
# 상수 연산
print(2023+1)
print(2023-1)
print(2023*1)
print(2023/3)
print(2023//3)
print(2023%3)
# Out:
# 2024
# 2022
# 2023
# 674.3333333333334
# 674
# 1

# %%
# 변수
a = 2024
print(a+1)
print(a-1)
print(a*2)
print(a/3)
print(a//3)
print(a%3)
# Out:
# 2025
# 2023
# 4048
# 674.6666666666666
# 674
# 2

# %%
print(a)
a+=1
print(a)
# Out:
# 2025

# %%
import keyword #모듈

print(keyword.kwlist) #변수로 지정 할 수 없는 키워드(명령어)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
name = "김창인"
address = "암사"
age = 25
pay=2500000

print('성명 : ' + name)
print(f'주소 : ', address)
print(f'나이 : ' + str(age))
print(f'급여 : {pay}')
# Out:
# 성명 : 김창인
# 주소 :  암사
# 나이 : 25
# 급여 : 2500000

# %%
print(pay + 5000000, '원')
# Out:
# 7500000 원

# %%
print(5*100+2)
print(5*(100+2))
# Out:
# 502
# 510

# %%
print('급여' ,'2000000'+'500000')
print('급여',int(2000000)+int(500000))
# Out:
# 급여 2000000500000
# 급여 2500000

# %%
point = 50
print(point+float('0.2'))
print(float(point)+0.5)
# Out:
# 50.2
# 50.5

# %%
name = ''
print(bool(name)) #문자열없음
name = ' '
print(bool(name)) #공백

name = "seoul"
print(type(name))
print(bool(name))
# Out:
# False
# True
# <class 'str'>
# True

# %%
var1 = 2020
var2 = var1 # 변수간 데이터 전달가능
print(var1, var2)

var2 = var2 + 3
print(var1, var2)
# Out:
# 2020 2020
# 2020 2023

# %%
# 입력 -> 처리 -> 출력
year = int(input('입사 년도를 입력하세요:'))
print('year:', year)
print(type(year))
year = year + 1
print('year:', year)
year = year + 1
print('year:', year)
# Out:
# 입사 년도를 입력하세요:2024
# year: 2024
# <class 'int'>
# year: 2025
# year: 2026

# %%
# print('2024' + 1) # X
print('2024' + ' 년') # 문자열 연결됨.
print(str(2024) + ' 년') # 문자열 연결됨.
# Out:
# 2024 년
# 2024 년

# %%
# 일수를 입력받아 시, 분, 초로 변환하여 출력하세요.
# 1일 24시간, 1시간은 60분, 1분은 60초
# 3일은 72시간, 4320 분, 259200 초임
day = int(input('일수를 입력하세요: '))
hour = day * 24
minute = hour * 60
second = minute * 60

print(str(day) + '일은 ' + str(hour) + ' 시간, ' + str(minute) + ' 분, ' + str(second) + ' 초임')
print('{0}일은 {1} 시간, {2} 분, {3} 초임'.format(day, hour, minute, second))
print('%d일은 %d 시간, %d 분, %d 초임' % (day, hour, minute, second))
print(f'{day}일은 {hour} 시간, {minute} 분, {second} 초임') # python 3.6 부터 제공

# %%
print(50000000)
print(format(50000000, ','))
print(f'나의 연봉: {format(28000000 + (3500000 * 5), ",")} 만원')
print(f'나의 연봉: {format(28000000 + (3500000 * 10), ",")} 만원')
print(f'나의 연봉: {format(28000000 + (3500000 * 15), ",")} 만원')
print(f'나의 연봉: {format(28000000 + (3500000 * 20), ",")} 만원')
# Out:
# 50000000
# 50,000,000
# 나의 연봉: 45,500,000 만원
# 나의 연봉: 63,000,000 만원
# 나의 연봉: 80,500,000 만원
# 나의 연봉: 98,000,000 만원
